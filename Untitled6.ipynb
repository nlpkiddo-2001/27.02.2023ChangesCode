# %% [markdown]
# <a href="https://colab.research.google.com/github/ZSGS-Vipin/27.02.2023ChangesCode/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hacknoon_data.csv')

# %%
df
# Out:
#       yr_mfr     fuel_type  kms_run  sale_price       city  body_type  \
# 0       2011        diesel   130494      380299  bengaluru      sedan
# 1       2014        petrol    86798      367999  bengaluru  hatchback
# 2       2011        petrol    38254      229699     mumbai  hatchback
# 3       2014        petrol    68678      389299    gurgaon  hatchback
# 4       2015        petrol   100330      537599      noida      sedan
# ...      ...           ...      ...         ...        ...        ...
# 5914    2012        petrol    32857      418199     mumbai      sedan
# 5915    2016        diesel    35413     1781537     mumbai        suv
# 5916    2015        diesel    46392      349199  new delhi  hatchback
# 5917    2010        petrol    33225      232699  bengaluru  hatchback
# 5918    2017  petrol & cng    92544      327399  faridabad  hatchback
#
#      transmission              variant      registered_city registered_state  \
# ...

# %%
x = df['make']
y = df['sale_price']

plt.scatter(x, y)


plt.xlabel('Column 1')
plt.ylabel('Column 2')
plt.title('Comparison of Column 1 and Column 2')

plt.show()

# %%
df.plot(x="make",y="sale_price",kind='bar')
# Out:
# <AxesSubplot:xlabel='make'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5919 entries, 0 to 5918
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   yr_mfr                 5919 non-null   int64
#  1   fuel_type              5919 non-null   object
#  2   kms_run                5919 non-null   int64
#  3   sale_price             5919 non-null   int64
#  4   city                   5919 non-null   object
#  5   body_type              5832 non-null   object
#  6   transmission           5463 non-null   object
#  7   variant                5919 non-null   object
#  8   registered_city        5913 non-null   object
#  9   registered_state       5913 non-null   object
#  10  make                   5919 non-null   object
#  11  model                  5919 non-null   object
#  12  approx_original_price  5919 non-null   int64
# dtypes: int64(4), object(9)
# memory usage: 601.3+ KB

# %%
df
# Out:
#       yr_mfr     fuel_type  kms_run  sale_price       city  body_type  \
# 0       2011        diesel   130494      380299  bengaluru      sedan
# 1       2014        petrol    86798      367999  bengaluru  hatchback
# 2       2011        petrol    38254      229699     mumbai  hatchback
# 3       2014        petrol    68678      389299    gurgaon  hatchback
# 4       2015        petrol   100330      537599      noida      sedan
# ...      ...           ...      ...         ...        ...        ...
# 5914    2012        petrol    32857      418199     mumbai      sedan
# 5915    2016        diesel    35413     1781537     mumbai        suv
# 5916    2015        diesel    46392      349199  new delhi  hatchback
# 5917    2010        petrol    33225      232699  bengaluru  hatchback
# 5918    2017  petrol & cng    92544      327399  faridabad  hatchback
#
#      transmission              variant      registered_city registered_state  \
# ...

# %%
print(df.isnull().sum())
# Out:
# yr_mfr                     0
# fuel_type                  0
# kms_run                    0
# sale_price                 0
# city                       0
# body_type                 87
# transmission             456
# variant                    0
# registered_city            6
# registered_state           6
# make                       0
# model                      0
# approx_original_price      0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 6))
df[['transmission', 'sale_price']].plot(kind='bar', ax=ax)

ax.set_title('Transmission vs. Sale Price')
ax.set_xlabel('Transmission')
ax.set_ylabel('Sale Price')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
df[['body_type', 'sale_price']].plot(kind='bar', ax=ax)

ax.set_title('Transmission vs. Sale Price')
ax.set_xlabel('Transmission')
ax.set_ylabel('Sale Price')

plt.show()

# %%
df = df.dropna()

# %%
print(df.isnull().sum())
# Out:
# yr_mfr                   0
# fuel_type                0
# kms_run                  0
# sale_price               0
# city                     0
# body_type                0
# transmission             0
# variant                  0
# registered_city          0
# registered_state         0
# make                     0
# model                    0
# approx_original_price    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 6))
df[['registered_city', 'sale_price']].plot(kind='bar', ax=ax)

ax.set_title('Transmission vs. Sale Price')
ax.set_xlabel('Transmission')
ax.set_ylabel('Sale Price')

plt.show()

# %%
df = df.drop(['registered_state','registered_city','approx_original_price'],axis=1)

# %%
df
# Out:
#       yr_mfr     fuel_type  kms_run  sale_price       city  body_type  \
# 0       2011        diesel   130494      380299  bengaluru      sedan
# 1       2014        petrol    86798      367999  bengaluru  hatchback
# 2       2011        petrol    38254      229699     mumbai  hatchback
# 3       2014        petrol    68678      389299    gurgaon  hatchback
# 4       2015        petrol   100330      537599      noida      sedan
# ...      ...           ...      ...         ...        ...        ...
# 5914    2012        petrol    32857      418199     mumbai      sedan
# 5915    2016        diesel    35413     1781537     mumbai        suv
# 5916    2015        diesel    46392      349199  new delhi  hatchback
# 5917    2010        petrol    33225      232699  bengaluru  hatchback
# 5918    2017  petrol & cng    92544      327399  faridabad  hatchback
#
#      transmission              variant       make          model
# ...

# %%
# !pip install Scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(df['fuel_type'])
# Out:
# LabelEncoder()

# %%
df
# Out:
#       yr_mfr     fuel_type  kms_run  sale_price       city  body_type  \
# 0       2011        diesel   130494      380299  bengaluru      sedan
# 1       2014        petrol    86798      367999  bengaluru  hatchback
# 2       2011        petrol    38254      229699     mumbai  hatchback
# 3       2014        petrol    68678      389299    gurgaon  hatchback
# 4       2015        petrol   100330      537599      noida      sedan
# ...      ...           ...      ...         ...        ...        ...
# 5914    2012        petrol    32857      418199     mumbai      sedan
# 5915    2016        diesel    35413     1781537     mumbai        suv
# 5916    2015        diesel    46392      349199  new delhi  hatchback
# 5917    2010        petrol    33225      232699  bengaluru  hatchback
# 5918    2017  petrol & cng    92544      327399  faridabad  hatchback
#
#      transmission              variant       make          model
# ...

# %%
df['fuel_type'] = le.fit_transform(df['fuel_type'])

# %%
df
# Out:
#       yr_mfr  fuel_type  kms_run  sale_price       city  body_type  \
# 0       2011          0   130494      380299  bengaluru      sedan
# 1       2014          2    86798      367999  bengaluru  hatchback
# 2       2011          2    38254      229699     mumbai  hatchback
# 3       2014          2    68678      389299    gurgaon  hatchback
# 4       2015          2   100330      537599      noida      sedan
# ...      ...        ...      ...         ...        ...        ...
# 5914    2012          2    32857      418199     mumbai      sedan
# 5915    2016          0    35413     1781537     mumbai        suv
# 5916    2015          0    46392      349199  new delhi  hatchback
# 5917    2010          2    33225      232699  bengaluru  hatchback
# 5918    2017          3    92544      327399  faridabad  hatchback
#
#      transmission              variant       make          model
# 0          manual                   gd     toyota          etios
# ...

# %%
print(df['fuel_type'].unique())
# Out:
# [0 2 3 4 1]

# %%
print(df['city'].unique())
# Out:
# ['bengaluru' 'mumbai' 'gurgaon' 'noida' 'hyderabad' 'pune' 'new delhi'
#  'lucknow' 'ahmedabad' 'chennai' 'faridabad' 'ghaziabad' 'kolkata']

# %%
print(df['body_type'].unique())
# Out:
# ['sedan' 'hatchback' 'suv' 'luxury sedan' 'luxury suv']

# %%
fig, ax = plt.subplots(figsize=(8, 6))
df[['city', 'sale_price']].plot(kind='bar', ax=ax)

ax.set_title('Transmission vs. Sale Price')
ax.set_xlabel('Transmission')
ax.set_ylabel('Sale Price')

plt.show()

# %%
df['city'] = le.fit_transform(df['city'])

# %%
df['body_type'] = le.fit_transform(df['fuel_type'])

# %%
df
# Out:
#       yr_mfr  fuel_type  kms_run  sale_price  city  body_type transmission  \
# 0       2011          0   130494      380299     1          0       manual
# 1       2014          2    86798      367999     1          2       manual
# 2       2011          2    38254      229699     9          2       manual
# 3       2014          2    68678      389299     5          2       manual
# 4       2015          2   100330      537599    11          2       manual
# ...      ...        ...      ...         ...   ...        ...          ...
# 5914    2012          2    32857      418199     9          2       manual
# 5915    2016          0    35413     1781537     9          0    automatic
# 5916    2015          0    46392      349199    10          0       manual
# 5917    2010          2    33225      232699     1          2       manual
# 5918    2017          3    92544      327399     3          3       manual
#
#                   variant       make          model
# ...

# %%
print(df['transmission'].unique())
# Out:
# ['manual' 'automatic']

# %%
df['transmission'] = le.fit_transform(df['transmission'])

# %%
print(df['variant'].unique())
# Out:
# ['gd' 'vxi bs iv' 'lxi' 'sportz 1.2 vtvt' 'zxi plus' '2.5 vx 8 str bs iv'
#  'v' 'era' 'magna 1.2 kappa2' 'delta 1.2 k12' 'asta 1.2 (o)'
#  'zxi 1.2 bs iv' 'sv mt petrol' 'xo erlx euro iii' 'sportz (o) 1.4'
#  '1.6 crdi sx plus auto' 'era plus' 'vdi abs' 'vl at' '35 tdi quattro'
#  '2.4 mt' 's mt petrol' 'vxi' '1.5 titanium ti vct' 'xt 1.2 revotron'
#  'vd sp' 'zdi' 'trendline 1.2l diesel' 'cla 200 cdi sport' 'lxi cng'
#  'vx mt petrol' 'magna o 1.2' 's 1.2' 'sportz 1.4' 'vx cvt petrol'
#  'xe 1.2 revotron' 'magna 1.2 vtvt' 'gt tsi 1.2 petrol at'
#  'asta 1.2 o with sunroof' 'asta 1.2 (o) vtvt' 'vx' '2.5 gx 7 str bs iv'
#  'vxi 1.2 bs iv' 'sports 1.2 vtvt' 'gxi' 'delta 1.2 k12 amt'
#  'fluidic 1.4 vtvt' 'sv mt diesel' '1.0 rxt' 'gls' 'asta 1.2' 'ldi' 'vdi'
#  'fluidic 1.6 vtvt s' 'vxi amt' 'vdi opt' 'zxi' 't (o)' 'sportz 1.2 o'
#  'sportz o 1.4 crdi' 'elegance 1.6 tdi mt' '2.5 vx 7 str bs iv'
#  '1.8 tsi lk at' 'h2 1.8 e' '1.2 base i vtec' 'vxi plus'
# ...

# %%
df['variant'] = le.fit_transform(df['variant'])

# %%
print(df['make'].unique())
# Out:
# ['toyota' 'maruti' 'hyundai' 'honda' 'audi' 'ford' 'tata' 'volkswagen'
#  'mercedes benz' 'renault' 'datsun' 'skoda' 'chevrolet' 'mahindra' 'jeep'
#  'nissan' 'bmw' 'mahindra renault' 'fiat' 'volvo' 'ssangyong' 'isuzu'
#  'opel' 'mitsubishi' 'jaguar']

# %%
plt.scatter(df['make'], df['sale_price'])

# Add labels and a title
plt.xlabel('make')
plt.ylabel('sale_price')
plt.title('Scatter plot of x versus y')

# Display the plot
plt.show()

# %%
plt.scatter(df['transmission'], df['sale_price'])

# Add labels and a title
plt.xlabel('transmission')
plt.ylabel('sale_price')
plt.title('Scatter plot of x versus y')

# Display the plot
plt.show()

# %%
df
# Out:
#       yr_mfr  fuel_type  kms_run  sale_price  city  body_type  transmission  \
# 0       2011          0   130494      380299     1          0             1
# 1       2014          2    86798      367999     1          2             1
# 2       2011          2    38254      229699     9          2             1
# 3       2014          2    68678      389299     5          2             1
# 4       2015          2   100330      537599    11          2             1
# ...      ...        ...      ...         ...   ...        ...           ...
# 5914    2012          2    32857      418199     9          2             1
# 5915    2016          0    35413     1781537     9          0             0
# 5916    2015          0    46392      349199    10          0             1
# 5917    2010          2    33225      232699     1          2             1
# 5918    2017          3    92544      327399     3          3             1
#
#       variant       make          model
# ...

# %%
print(df['body_type'].unique())
# Out:
# [0 2 3 4 1]

# %%
seating_map = {0: 5, 1: 8, 2: 7, 3: 7, 4: 4}
df['seating'] = df['body_type'].map(seating_map)

# %%
df
# Out:
#       yr_mfr  fuel_type  kms_run  sale_price  city  body_type  transmission  \
# 0       2011          0   130494      380299     1          0             1
# 1       2014          2    86798      367999     1          2             1
# 2       2011          2    38254      229699     9          2             1
# 3       2014          2    68678      389299     5          2             1
# 4       2015          2   100330      537599    11          2             1
# ...      ...        ...      ...         ...   ...        ...           ...
# 5914    2012          2    32857      418199     9          2             1
# 5915    2016          0    35413     1781537     9          0             0
# 5916    2015          0    46392      349199    10          0             1
# 5917    2010          2    33225      232699     1          2             1
# 5918    2017          3    92544      327399     3          3             1
#
#       variant       make          model  seating
# ...

# %%
df['make'] = le.fit_transform(df['make'])

# %%
df['model'] = le.fit_transform(df['model'])

# %%
df
# Out:
#       yr_mfr  fuel_type  kms_run  sale_price  city  body_type  transmission  \
# 0       2011          0   130494      380299     1          0             1
# 1       2014          2    86798      367999     1          2             1
# 2       2011          2    38254      229699     9          2             1
# 3       2014          2    68678      389299     5          2             1
# 4       2015          2   100330      537599    11          2             1
# ...      ...        ...      ...         ...   ...        ...           ...
# 5914    2012          2    32857      418199     9          2             1
# 5915    2016          0    35413     1781537     9          0             0
# 5916    2015          0    46392      349199    10          0             1
# 5917    2010          2    33225      232699     1          2             1
# 5918    2017          3    92544      327399     3          3             1
#
#       variant  make  model  seating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5463 entries, 0 to 5918
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr_mfr        5463 non-null   int64
#  1   fuel_type     5463 non-null   int64
#  2   kms_run       5463 non-null   int64
#  3   sale_price    5463 non-null   int64
#  4   city          5463 non-null   int64
#  5   body_type     5463 non-null   int64
#  6   transmission  5463 non-null   int64
#  7   variant       5463 non-null   int64
#  8   make          5463 non-null   int64
#  9   model         5463 non-null   int64
#  10  seating       5463 non-null   int64
# dtypes: int64(11)
# memory usage: 512.2 KB

# %%
df.to_csv('cleaned_hacknoon.csv')

# %%
from google.colab import files

# %%
df.to_csv('cleaned_hacknoon.csv', index=False)
files.download('cleaned_hacknoon.csv')

# %%
y = df['sale_price'].values
X = df.drop(['sale_price'],axis=1)

# %%
y
# Out:
# array([380299, 367999, 229699, ..., 349199, 232699, 327399])

# %%
X
# Out:
#       yr_mfr  fuel_type  kms_run  city  body_type  transmission  variant  \
# 0       2011          0   130494     1          0             1      337
# 1       2014          2    86798     1          2             1      585
# 2       2011          2    38254     9          2             1      408
# 3       2014          2    68678     5          2             1      499
# 4       2015          2   100330    11          2             1      671
# ...      ...        ...      ...   ...        ...           ...      ...
# 5914    2012          2    32857     9          2             1      328
# 5915    2016          0    35413     9          0             0      154
# 5916    2015          0    46392    10          0             1      491
# 5917    2010          2    33225     1          2             1      401
# 5918    2017          3    92544     3          3             1      411
#
#       make  model  seating
# 0       22     51        5
# 1       13    112        7
# ...

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
standardScaler.fit(X)
# Out:
# StandardScaler()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=69)

# %%
X_train
# Out:
#       yr_mfr  fuel_type  kms_run  city  body_type  transmission  variant  \
# 5037    2008          2    76422     4          2             1      410
# 807     2012          2    52419     1          2             1      303
# 1436    2011          0   122631     8          0             1      323
# 34      2012          0    77208     1          0             1      532
# 2504    2010          2    87265     9          2             1      223
# ...      ...        ...      ...   ...        ...           ...      ...
# 3930    2015          0   158343    12          0             1       66
# 473     2016          2    27245    10          2             1      408
# 1739    2019          3    17417    12          3             1      186
# 2872    2015          0    81879     2          0             1       61
# 4358    2011          3    57156     9          3             1      574
#
#       make  model  seating
# 5037    13    128        7
# 807      7     67        7
# ...

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

params = {
    'objective': 'reg:squarederror',
    'max_depth': 4,
    'learning_rate': 0.08,
    'n_estimators': 500
}

xgb_model = xgb.XGBRegressor(**params)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

y_pred = xgb_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.865700050705225

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

params = {
    'n_estimators': 200,
    'max_depth': 15,
    'min_samples_split': 2,
    'min_samples_leaf': 1,
    'random_state': 69
}


rf_model = RandomForestRegressor(**params)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 12377937223.66017

# %%
from sklearn.metrics import r2_score

y_pred = xgb_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.865700050705225

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)


svr.fit(X_train, y_train)


y_pred = svr.predict(X_test)


mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 274077.44

# %%
from sklearn.metrics import r2_score

y_pred = xgb_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.865700050705225
